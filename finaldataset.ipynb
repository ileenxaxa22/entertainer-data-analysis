# %%
import pandas as pd

# %%
#eb= Entertainer basic table
#ebt = entertainer breakthrough
#el = entertainer lastwork

# %%
eb = pd.read_csv('/content/Entertainer - Basic Info.csv')
eb.head()
# Out:
#        Entertainer Profession Gender (traditional)  Birth Year
# 0            Adele     Singer                    F        1988
# 1   Angelina Jolie      Actor                    F        1975
# 2  Aretha Franklin     Singer                    F        1942
# 3      Bette Davis      Actor                    F        1908
# 4      Betty White      Actor                    F        1922

# %%
ebt = pd.read_csv('/content/newbreakthrough.csv')
ebt.head()
# Out:
#        Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0            Adele                                          2008
# 1   Angelina Jolie                                          1999
# 2  Aretha Franklin                                          1967
# 3      Bette Davis                                          1934
# 4      Betty White                                          1952
#
#                           Breakthrough Name Year of First Oscar/Grammy/Emmy
# 0                                        19                          2009.0
# 1                         Girl, Interrupted                          1999.0
# 2  I Never Loved a Man (The Way I Love You)                          1968.0
# 3                          Of Human Bondage                          1935.0
# 4                      Life with Elilzabeth                          1976.0

# %%
ebt.drop('Entertainer',inplace=True,axis=1)

# %%
ebt.head()
# Out:
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name Year of First Oscar/Grammy/Emmy
# 0                                        19                          2009.0
# 1                         Girl, Interrupted                          1999.0
# 2  I Never Loved a Man (The Way I Love You)                          1968.0
# 3                          Of Human Bondage                          1935.0
# 4                      Life with Elilzabeth                          1976.0

# %%
el = pd.read_csv('/content/newlastwork.csv')
el.drop('Entertainer',inplace=True,axis=1)
el.head()
# Out:
#    Year of Last Major Work (arguable) Year of Death
# 0                                2016       Unknown
# 1                                2016       Unknown
# 2                                2014       Unknown
# 3                                1989        1989.0
# 4                                2016       Unknown

# %%
# concating the first two tables (eb and ebt)

# %%
main1 = pd.concat([eb,ebt],axis=1)
main1.head()
# Out:
#        Entertainer Profession Gender (traditional)  Birth Year  \
# 0            Adele     Singer                    F        1988
# 1   Angelina Jolie      Actor                    F        1975
# 2  Aretha Franklin     Singer                    F        1942
# 3      Bette Davis      Actor                    F        1908
# 4      Betty White      Actor                    F        1922
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name Year of First Oscar/Grammy/Emmy
# 0                                        19                          2009.0
# 1                         Girl, Interrupted                          1999.0
# 2  I Never Loved a Man (The Way I Love You)                          1968.0
# 3                          Of Human Bondage                          1935.0
# 4                      Life with Elilzabeth                          1976.0

# %%
main=pd.concat([main1,el],axis=1)

# %%
main.head()
# Out:
#        Entertainer Profession Gender (traditional)  Birth Year  \
# 0            Adele     Singer                    F        1988
# 1   Angelina Jolie      Actor                    F        1975
# 2  Aretha Franklin     Singer                    F        1942
# 3      Bette Davis      Actor                    F        1908
# 4      Betty White      Actor                    F        1922
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name Year of First Oscar/Grammy/Emmy  \
# 0                                        19                          2009.0
# 1                         Girl, Interrupted                          1999.0
# 2  I Never Loved a Man (The Way I Love You)                          1968.0
# 3                          Of Human Bondage                          1935.0
# 4                      Life with Elilzabeth                          1976.0
#
#    Year of Last Major Work (arguable) Year of Death
# 0                                2016       Unknown
# 1                                2016       Unknown
# 2                                2014       Unknown
# 3                                1989        1989.0
# 4                                2016       Unknown

# %%
main.shape
# Out:
# (70, 9)

# %%
main.to_csv("pendingentertainer.csv",index=False)
